# %% [markdown]
# ## 05 -- XGBoost Regressor
#
# Trains an XGBoost gradient-boosted tree model to predict next-24-hour PM2.5.
# Same temporal split and RandomizedSearchCV approach as the Random Forest notebook.

# %%
import pathlib, warnings
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error, classification_report
warnings.filterwarnings('ignore')

# %%
# Load feature-engineered dataset
PROC = pathlib.Path('../data/processed')
df = pd.read_csv(PROC / 'features_engineered.csv', parse_dates=['datetime'])

FEATURE_COLS = [
    'o3', 'no2', 'pm25',
    'temperature_2m', 'relative_humidity_2m', 'wind_speed_10m',
    'wind_direction_10m', 'precipitation', 'surface_pressure',
    'hour', 'day_of_week', 'month', 'is_weekend',
    'pm25_lag_1', 'pm25_lag_2', 'pm25_lag_3', 'pm25_lag_24',
    'pm25_roll_24h', 'pm25_roll_72h',
]
TARGET_COL = 'pm25_next24h'

# Drop rows with any NaN in features or target
model_df = df.dropna(subset=FEATURE_COLS + [TARGET_COL]).copy()
print(f'Rows available: {len(model_df):,}  (dropped {len(df) - len(model_df):,} with NaN)')
print(f'Date range    : {model_df["datetime"].min().date()}  to  {model_df["datetime"].max().date()}')
model_df.head(3)
# Out:
# Rows available: 74,543  (dropped 6,485 with NaN)
# Date range    : 2023-01-02  to  2024-12-30
#               datetime                       city        o3       no2   pm25  \
# 34 2023-01-02 13:00:00  Birmingham A4540 Roadside  35.62324  32.43474  3.797
# 35 2023-01-02 14:00:00  Birmingham A4540 Roadside  33.27830  42.81079  4.080
# 36 2023-01-02 15:00:00  Birmingham A4540 Roadside  32.57980  41.95037  4.599
#
#     temperature_2m  relative_humidity_2m  wind_speed_10m  wind_direction_10m  \
# 34             6.2                    79             9.7                 243
# 35             6.2                    79            11.4                 242
# 36             5.5                    85             9.4                 238
#
#     precipitation  ...  day_of_week  month  is_weekend  pm25_lag_1  \
# 34            0.0  ...            0      1           0       3.986
# 35            0.0  ...            0      1           0       3.797
# 36            0.0  ...            0      1           0       4.080
#
#     pm25_lag_2  pm25_lag_3  pm25_lag_24  pm25_roll_24h  pm25_roll_72h  \
# 34       4.198       4.104        8.632       5.766542       5.710833
# 35       3.986       4.198        9.033       5.565083       5.659108
# 36       3.797       3.986        9.646       5.358708       5.617553
#
#     pm25_next24h
# 34         2.995
# 35         3.042
# 36         4.646
#
# [3 rows x 22 columns]

# %%
# Temporal train / test split  -- test = 2024-Q4 (Oct-Dec)
SPLIT_DATE = '2024-10-01'

train = model_df[model_df['datetime'] < SPLIT_DATE]
test  = model_df[model_df['datetime'] >= SPLIT_DATE]

X_train, y_train = train[FEATURE_COLS].values, train[TARGET_COL].values
X_test,  y_test  = test[FEATURE_COLS].values,  test[TARGET_COL].values

print(f'Train: {len(train):,} rows   ({train["datetime"].min().date()} to {train["datetime"].max().date()})')
print(f'Test : {len(test):,} rows    ({test["datetime"].min().date()} to {test["datetime"].max().date()})')
# Out:
# Train: 64,049 rows   (2023-01-02 to 2024-09-30)
# Test : 10,494 rows    (2024-10-01 to 2024-12-30)

# %%
import xgboost as xgb
from sklearn.model_selection import GridSearchCV, TimeSeriesSplit

# 2x2 grid = 8 fits total -- fast with XGBoost hist backend
param_grid = {
    'max_depth':     [4, 6],
    'learning_rate': [0.05, 0.1],
}
tscv = TimeSeriesSplit(n_splits=2)

search = GridSearchCV(
    xgb.XGBRegressor(n_estimators=200, subsample=0.8, colsample_bytree=0.8,
                     tree_method='hist', random_state=42),
    param_grid=param_grid,
    cv=tscv,
    scoring='neg_root_mean_squared_error',
    n_jobs=1,
    verbose=1,
)
search.fit(X_train, y_train)

print('Best params:', search.best_params_)
print(f'Best CV RMSE: {-search.best_score_:.3f} ug/m3')
# Out:
# Fitting 2 folds for each of 4 candidates, totalling 8 fits
# Best params: {'learning_rate': 0.05, 'max_depth': 6}
# Best CV RMSE: 4.700 ug/m3

# %%
import xgboost as xgb

best_xgb = xgb.XGBRegressor(**search.best_params_, tree_method='hist', random_state=42)
best_xgb.fit(X_train, y_train)
y_pred = best_xgb.predict(X_test)

# %%
# DAQI PM2.5 band classification (24-h mean, ug/m3)
def daqi_band(x):
    if x < 12:  return 'Low'
    elif x < 24: return 'Moderate'
    elif x < 48: return 'High'
    else:        return 'Very High'

y_pred = np.clip(y_pred, 0, None)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mae  = mean_absolute_error(y_test, y_pred)
print(f'Test RMSE : {rmse:.3f} ug/m3')
print(f'Test MAE  : {mae:.3f} ug/m3')

y_true_band = [daqi_band(v) for v in y_test]
y_pred_band = [daqi_band(v) for v in y_pred]
bands = ['Low', 'Moderate', 'High', 'Very High']
print()
print('DAQI band classification:')
print(classification_report(y_true_band, y_pred_band, labels=bands, zero_division=0))
# Out:
# Test RMSE : 5.143 ug/m3
# Test MAE  : 3.777 ug/m3
#
# DAQI band classification:
#               precision    recall  f1-score   support
#
#          Low       0.85      0.95      0.90      8353
#     Moderate       0.41      0.28      0.33      1782
#         High       0.44      0.01      0.02       356
#    Very High       0.00      0.00      0.00         3
#
#     accuracy                           0.80     10494
#    macro avg       0.43      0.31      0.31     10494
# weighted avg       0.76      0.80      0.77     10494

# %%
MODEL_DIR = pathlib.Path('../models')
MODEL_DIR.mkdir(exist_ok=True)

importances = pd.Series(best_xgb.feature_importances_, index=FEATURE_COLS)
importances = importances.sort_values(ascending=True).tail(15)

fig, ax = plt.subplots(figsize=(7, 5))
importances.plot.barh(ax=ax, color='darkorange')
ax.set_xlabel('Feature importance')
ax.set_title('XGBoost -- top 15 features')
plt.tight_layout()
plt.savefig(MODEL_DIR / 'xgb_feature_importance.png', dpi=120)
plt.show()
print('Feature importance plot saved.')
# Out:
# Feature importance plot saved.

# %%
MODEL_DIR = pathlib.Path('../models')
MODEL_DIR.mkdir(exist_ok=True)
best_xgb.save_model(str(MODEL_DIR / 'xgboost.json'))
print('Model saved to models/xgboost.json')
# Out:
# Model saved to models/xgboost.json
